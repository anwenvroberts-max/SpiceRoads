# %% [markdown]
# # Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import requests
import time

#import matplotlib.pyplot as plt
#import seaborn as sns

# %% [markdown]
# # Importing Data - COMTRADE API - Anwen

# %%
# path, URL or csv/excel import here

# %% [markdown]
# --> Make Main DF for COMTRADE Chili data (CT)  - TODO

# %%
# make main df like CT_chili_data = get COMTRADE API - code here! 

# for Eurostat Api (ES), make a NEW main df like ES_chili_data below! Don't overwrite the CT dfs!
# --> TODO A. - working on API get code rn!

# %%
# Code for Comtrade CSV / JSON datasets goes here! --> TODO

# %% [markdown]
# # Cleaning Data
#
# Use at least 5 data cleaning and structuring methods, per project instructions
#     "Apply at least five data cleaning techniques, such as handling null values, dropping columns, removing duplicated data, manipulating strings, formatting the data, etc., to prepare the dataset for analysis."

# %%
# CT_chili_data.head()

# %%
# check size for dataframe
# CT_chili_data.head().shape

# %%
# checking for NaN values
# CT_chili_data.isnull().sum()

# %%
# Make NEW df CT_clean or similar! CAREFUL WITH FILENAMES 

# Dropping NaN & legacy columns from excel file
# Example - CT_data_clean = CT_chili_data.drop(columns=[ NN ]) # ADD Cols here

# %%
# Check Shape occasionally
# CT_data_clean.shape

# %%
# Dropping columns with drop(columns=[...]) method 
# CODE HERE

# Check cleaned ds
CT_data_clean.head()

# %%
# Change column names and standardize if needed 

# Check for Null Values 
CT_data_clean.isnull().sum()

# %%
# check unique values in all columns - only if needed for further cleanup D3
CT_data_clean.nunique()

# %%
# Take decisions on which extra columns to drop, and how to standardize outputs 
#   KEEP the DESC (description) Cols and DROP the codified Var before that!

# Identify problem fields --> see planning file A. - Todo ALL

# %%
# Check Columns separately - only if needed 
# CT_data_clean['COLUMN NAME'].value_counts()

# %%
# Individual Columns Cleanup - FILL IN HERE!

# CT_data_clean.describe() # Print out current DF

# %%
# Handling years bins - make one complete file (CT starts 1988?) and one df for 2020 - TODO

# like 
# CT_year_data = CT_data_clean[CT_data_clean[" YEAR COL "].notna()]
# CT_year_data = CT_data_clean[CT_data_clean[" YEAR COL "] >= 2020

# CODE HERE

# %%
# Types casting and converting cols - TODO

# make Revenue ($) values and Trade volume (kg) into float columns, cast binary data like Y/N to ints 1/0 
# TIME Variables - get fine grained CT data by month, week, day if possible - TODO

# %% [markdown]
# ##  Create our own DF for VARIETIES LEXICON

# %%
# Create new columns - TODO
# Favourite Chili Varieties for partner countries --> M - getting this info from CT and IMPLIED AI Variety mapping - DONE!

# Todo- Analysis D3/D4

# %%
 # Create DF for Species [] and Varieties [] for CHILI LEXICON - TODO

# %%
# Cleanups if needed - with .value_counts() AND .str.strip().str.lower()

# Like clean_df["COL Name"] =  clean_df["COL Name"].str.strip().. etc
# TODO

# %% [markdown]
# ## Mykyta - Analysis CT Data by countries --  Goes here !!

# %%
# MYKYTA WORKBOOKS & JSON -- add in here! 

# Generate df tables for DE - PL - UK for 2020-2025

# Generate Country - only if we have the data - no AI as data SOURCE!

# %%
# Review what else needs to be done on COMTRADE sets together - TODO

# %% [markdown]
# ## Anwen - Analysis ES api Data by countries -- Goes here !!

# %%
# MAKE ENTIRE NEW DF FOR ES API DATA - DO NOT RENAME DF!! 

# get Eurostat Api (ES) - USES ITS OWN DS CODE SYSTEM - NOT HS CODES! 
# make a NEW main df like ES_chili_data below! Don't overwrite the CT dfs!

# --> TODO A. - working on API get function rn! D3

# %%
# Code mockup for Eurostat API - copy here --> Anwen D3 TODO (I have almost working code, testing!)

# %% [markdown]
# ## Edson - Analysis of Demographic Data -- Goes here !!

# %%
# Code mockup for Demographics data --> Edson & Anwen D3 TODO 

# Just get top 10 migrant demographics for our 3 countries - Obvious choices to look at: 
#    DE: Turkish and Arab/MENA influences
#

# %% [markdown]
# ## VARIETIES DATA COLLECTION
#
# --> Discuss Priorities/Tasks! TODO

# %%
# Make our own "LEXICON" of Chili varieties --> E & A TODO
# CATEGORICAL / QUANTITATIVE data - save in df or xl table in our repo>data

# %%
# Make VARIETIES list TODO
# Collect from top tyoes, and our Slack chats! 

varieties = [] # Our list here ## JOIN LISTS WITH EDSON LISTS

# %% [markdown]
# ## EDSON Wp SCRAPING TOOL --> WORKING PROTOTYPE - DONE

# %%
# XL Sheet --> TODO

# Scraped WP images --> EDSON Code mockup - DONE!

# %%
# Make SPECIES List and PIVOT table with VARIETIES --> TODO

species = [] # Our list here 

# Pivot dfs with *wide* format Species > Variety > Variety cols... - TODO
# Wikipedia INFOCARDS - for Varieties ?

# %%
# LOW Priority for D3 - make Basic mockup first, PRETTIFY on D4

# %% [markdown]
# ## DATA VIZ IDEAS / FINAL PRODUCT - DAY 04

# %%
# Our data viz, plots and Research Results here --> D4 TOdo
