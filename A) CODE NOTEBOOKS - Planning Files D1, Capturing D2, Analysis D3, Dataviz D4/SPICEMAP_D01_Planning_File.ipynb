# %% [markdown]
# ## BOOTCAMP Week03 -- PROJECT "SpiceMap": ANALYZING GLOBAL CHILI PEPPER TRADE DATA
# # Team: Anwen, Edson, Mykyta (A, E, M)

# %% [markdown]
# # CONTENTS
#
# 0. Project Planning, Kanban/Todos
#
# 1. General Idea - Conceptualizing, making data decisions - Day1
# 2. Data Collection, Aggregation and Cleanup - Day2 --> ipy nb "Data Collection"
# 3. Data Analysis - Day3 --> ipy nb "Data Analysis"
# 4. Data Viz - Day4 --> ipy nb "Research/Results" NN
# 5. Live MVP Demo & Prezi - Day5

# %% [markdown]
# ### 0. PROJECT OVERVIEW & KANBAN BOARD -- PASTE TO NOTION/MONDAY BOARD!
# # Team: Anwen, Edson, Mykyta (A, E, M)
# A anwen.v.roberts@gmail.com - E geschaft23@gmail.com - M nickel.rjaba@gmail.com
#
# # TODOs
# -Timeline / TODOS by Day and team member --> All: pay attention to Project specifics on Student Portal & project Slack channel!
#     --> M - share KANBAN board for tasks! Screenshot monday status in Slack Nairobi group - DONE
#     --> A - make Notion or similar board for all tasks in one place, merge with M's Todolist - TODO for D3
# # THIS TODO/OVERVIEW WILL BE OUTSOURCED TO ONE COMMON GROUP KANBAN, as GH repo file or Notion board!
# - Mykyta Riabchynskyi  [09:29 Uhr] https://bloodnickel.monday.com/boards/18408417091 - Monday website unusable :/
# # Nerd alternative TaskWarrior instead of Trello, Monday, Notion -- CL tool for task management & Kanban board
#     https://taskwarrior.org/docs/start/
#
# - make GH repo --> M - DONE --  https://github.com/bloodnickel/nairoby-project
#     2 ipynb notebooks + README file -- our data gathering D2 and analysis D3 nbs from Day2 & Day3 --> A. making repo folders
#         --> A: making D2 data collection nb today, will fork M's repo and share GH links in Slack - TODO
#         --> TODO: Save pkl file before! we start analysis on D3, Make new Data analysis ipy nb for Day3 --> NN
#
#     >Data folder -for our extracted df csv and xl files --> M - hosts & manages the shared GH repo - DONE
#     >Charts/Visuals - folder for our presentation and research findings/analysis --> Prettify everything on D4
#     PRESENTATION - make mockup for slideshow --> NN (A. has an idea and a good template, can share) --> NN not urgent- Day4 Data Viz
#
# - METHODS COVERED - DECIDE WHAT WE NEED; NOT ALL OPTIONS NEEDED; PRIORITIZE/ TIME MANGEMENT - DONE -->  Chat with ADI about open Qs
# - Adi: "just tick all the boxes" --> (1. API usage, 2. Data Wrangling, Collecting, Scraping, 3. Descriptive Analysis and Data Viz of our results - just to show we know what we're doing!)

# %% [markdown]
# ## DATA SOURCES & API/GET STRATEGY - APIs (Comtrade CT & Eurostat ES), Public Datasets, Web Scraping, Own data generation (Varieties/Species file)
#
# 1.  APIs - Data Collection & Parsing - Day2&3
#
#     - Comtrade DB
#         --> M - Fresh Capsicum HS 070960 and 09042x Datasets; country data by varieties and time vars - D2 / in progress!
#         --> A - DRIED/FLAKED + CONDIMENTS datasets; check Eurostat API for usefulness, get ES dataset DS-045409 for analysis -TODO D3
#     - Eurostats DB
#         --> A: Check DB just for data for our 3 countries - TODO -- we can use the ES datasets for API challenge like Adi suggested!
#         --> E: Compare with global Comtrade and/or Eurostat import data if needed? To infer Chili Varieties and map to origin country
#         --> check out Code 07096099 ("Other Capsicum")? - TODO NN
#
# 2. WEB SCRAPING & OWN DATA GATHERING/COMPILATION - Day3#
#
#     - Wiki data for VARIETIES - make a xl File, export to CSV later D4 so we show all >Data statistics etc in CSV Format! - TODO All
#         --> E & A: Explore options for mapping sub species/varieties to origin countries?
#         --> TODO: Start our own file with the list of capsicums we want to feature, where we can compile all Variety Info - NN TODO
#     - supermarket product lists --> A: check if scraping possible time and effort wise - low priority
#     - Recipe scraping Mockup --> A: already worked it out, low priority (RQ 4 or 5, if time)
#
# 3. DATA VIZ & FINAL PRODUCT - Day4
#
#     - Edson hat great ideas on featuring individual chili varieties; making a Scoville Spice-o-meter for countries; different "Playing cards" with info for all the different chilis. We should def. make our own df columns SPECIES =["Capsicum annum", "Caps.." etc] and VARIETY =["Bhut Jolokia", "BirdsEye", ...] PIVOT table - [Species] [Variety] df
#         --> make [Species] and [Variety] lists and dfs - TODO NN.!
#
#     - GLOBAL Pungency Index - country comparison/map, codifying High Scoville products --> A: if time, low priority for Day4
#         --> A: will look at codifying "spiciness" by Scoville scale and country, in progress - see "planning file" ipynb on GH
#         --> M: explain to E&A what Comtrade DS can tell us for sub species / variety? TODO
#
#     - Chili Varieties Lexicon - scrape wikidata objects to make small cards for our types
#         --> E - but all can provide infos to central file D3&4
#     Lexicon style for species [capsicum annum, ..] and Varieties lists [jalapeno, jolokia, ...]
#         --> map subspecies Habanero, Piripiri, etc? --> E&A - check what if anything to be done with Chili Variety data -- TODO
#         --> E: example code for wikip. scraping? TODO, low priority

# %% [markdown]
# ## 1. PROJECT PLANNING - DAY 01 MONDAY

# %% [markdown]
# ## 1. PROJECT PLANNING
#
# - Concept/General Idea - fill in here from Anwen's NOTES, make PPT/Prezi structure -TODO NN
#
# - Goal of Data Analysis - Summarize - TODO NN
#
# ## RESEARCH DESIGN & HYPOTHESES --> ADI RECOMMENDED !AT LEAST THREE! EXPLORATIONS/ DIRECTIONS OF RESEARCH!
# - A: this is my suggestion to realize Adi's advice and how we could split them up for presentation
#
# - We each present ONE of them in the Day5 Demo, but for analysis D3 we all work on all Qs together right? --> Discuss on D3 TODO
# - Combine qualitative AND quantitative results in Analysis when we check back in together on D3 --> TODO on Day3 & Day4, not urgent
#
#     1. Quantitative --> M - Comtrade data by country - DONE
#                     --> A - Eurostat Dataset by country TODO
#                     --> E - migration demographic data for our 3 countries TODO
#     2. Qualitative --> Country and Chili Variety & Product infos -- webscraping - ONLY IF TIME, scraping is time consuming..
#
# # CORE AREAS IDENTIFIED FOR ANALYSIS ON D2 --> Turn into RQs & Hypotheses --> A: DONE - if I missed any, E & M plz add missing points!
#
# ## RESEARCH DESIGN & EDA --> Dataframe cleanup needed TODO -- dropna columns, rename headers, replace vals.. -NN
#
# # Research Design Summary & Project Status:
#
# 1. The "Immigration Factor" - doable
# 2. The "Regulation Gap" - doable with EStat API
# 3. The "Global Heat Map" - low priority, don't over complicate!
#     A. Bland vs. Spicy: Case study of 3 regional cuisines - DE, UK, PL.
#         --> All: Profiles of extreme Chili varieties;
#         --> Hot Sauce/Novelty Food trends - TODO low priority, if time
#     (B. GLobal Spiciness Index & Country Maps (Pivot: just quantify Scoville * Variety data) --> A: low priority, only if time!)
#
# EXTRAS / NICE TO HAVE -- if we have time:
# 4. The "Sauce Shift" - Novelty hot sauces with long shelf life, vs. EU produced sauces
#     - Is FRESH produce also used in our target countries to then PRODUCE eg, hipster hot sauces?
#     --> M had this idea, make it into concrete RQ or drop?
#
# 5. The "Heat Wave" - Historical data and timeline analysis to include data eg. 2000-2020
#     --> make extra df for 2000-2020 data in portable format - TODO, low prio if time
#     - if we use "historical" trade timeline data, we can track other EU food regulation effects
#     (Case study possible: influx of mio.Scoville, hardcore sauces from US and LatAm market (Naga/Reaper/Habanero) since 90s/2000s)

# %% [markdown]
# ## Research Questions & Hypotheses; Research Design and Goals of Analysis

# %% [markdown]
# ## RQs & Hypotheses -- Details
#
# # 1. The "Immigration Factor" - M can present, knows the Comtrade DB? But all help with the respective data gathering
# HYPOTHESIS: TODO --> All: Collect our explicit assumptions D3
# RQ: How does the rise in chili imports correlate with the growth of specific diaspora populations in those countries?
# Data sources:
# - diaspora/EU migration data by country to get influential migrant cuisines --> E - TODO
# - comtrade im/export data by country --> M - in progress
# CASE STUDY: Main Focus on 3 regional Importers / Cuisines - UK, DE, PL. --> M: Clean matching Comtrade data TODO
#
# (CASE STUDY - only if we have time! Idea: Show how Arab and Turkish cuisine influence is visible in Chili Varieties chosen in Germany?
# Compare FRESH produce with -- DRY Kebab and Asian restaurant flakes--often Aleppo pepper=pul biber from Turkiye -- Compare vs Harissa -staple SAUCE condiment --canned, less perishable, mostly Baklouti/Cheyenne from Tunisia. --> What about Mexican and US "hardcore" varieties - if there is time for data analysis before 2020 also! -TODO NN)
#
# # 2. The "Regulation Gap" - A can present, but all help with the respective data gathering
# HYPOTHESIS: TODO --> All
# RQ: How do EU bans of certain high-heat products affect markets?
# Data sources:
# - Create dfs for Fresh, Dried/Ground, Condiment/Sauce tables from Comtrade and Eurostat --> TODO - A & M
# - (Legal status, EU directives --> could be used to correlate with trade timelines/development, if we have time -NN)
#
# CASE STUDY: "One Chip Challenge"/Paqui - Massive Effect on EU legislation visible?
#     --> A - see if our data would allow this analysis, make mockup - TODO
#     (Condiments and preserves have much longer shelf life and are not as perishable goods!) --> TODO Clean datasets if needed- All
#     --> A - see if Eurostats DB can be used for this Q, extract only the Data for our 3 target countries - in progress!
#     --> find exact timing/daily or weekly stats - TODO. low priority D4 timeline dataviz -NN
# - What are the trends in consumption of FRESH capsicum, compared to DRIED/FLAKE pepper, compared to Hot SAUCES
#
#
# # 3. The "Pungency Map" - E can present, but all help with the respective data gathering
# HYPOTHESIS: TODO
# RQ: Have "bland" cuisines changed measurably in recent years contrary to their reputations?
# - Bland vs. Spicy National Cuisines
#     --> All 3 target countries DE, UK, PL not exactly known for their use of spices...
# CASE STUDY: Hot Britannia! Eg, find out if the UK actually is that "bland" anymore? Cuisines & eating/health habits have changed
#     --> Our data will likely confirm that UK is one of the biggest consumers of chilies in Europe, again in great parts due to the Pakistani-Indian diaspora
# Data sources: Compiled Estat and Comtrade dfs, OWN research like (cuisine pungency by target country)
#
# # NOTES
# # RQ 4 & 5 - low priority, only if enough time --> All: think about research design, hypotheses & Results we want.
# # HOW TO CODIFY "SPICINESS" OF A COUNTRY? --> TODO A - looking into it, low Prio/if time
# # UK AS CASE STUDY?
#     RQ - All our example countries are not known for their use of spices... But is the UK actually that "bland" anymore?
#     - Our data will likely confirm that UK is actually among the greatest consumers of hot chilies in Europe
#     - and that this is likely also in great parts due to the Pakistani-Indian diaspora - Brick Lane curryhouse effect since ca.1970s
#     (We can do similar for Germany data, and PL if we find sth interesting?
#         DE: Turkish, Arab, Vietnames/E.Asian communities, restaurant, fast food sector - Kebab Shops, Taco Trend, influx of Syrian, Lebanese migrants and refugees)

# %% [markdown]
# ### 2. DATA CLEANING -- Day 02 Tuesday
#
# - make ONE ipynb for all cleaned and gathered data --> share to M's repo? TODO
#
# - Comtrade DB --> integrate M's notebook here
# - Eurostats API --> A - in progress, finish by Tue 18pm!
# - additional ds --> Migration countries
#
# - Data compilation on Chili Varieties - Lexicon? --> Edson

# %% [markdown]
# ### 3. DATA ANALYSIS -- Day 03 Wed
#
# - make ONE ipynb for ANALYSIS data --> make PKL file at the end of Day 03, share to M's repo TODO
#
# - Compile our aggregated VARIETY/SPECIES data in xl or md NB
#
# - ALL: Quantitative Data Study - save result tables and graphs to GH repo > data
#
#     E - Demographic data analysis; Variety data collection
#     M - Comtrade country DE/UK/PL and timeline analysis 2020-2025
#     A - Eurostat complete DS collection; Diaspora data analysis w. E; organizing files and code compatibility in planning file
#
# - Coding additional graphs and scraping tools we need
#
#     E - prototype for Wikipedia scraping of Chili Images and Captions - DONE!
#     NN - Country import TIMELINES 2020 thru 2025 for DE/UK/PL

# %% [markdown]
# ### 4. DATA VIZ -- Day 04

# %% [markdown]
# # Incorporate Edson's VIZ & PREZI Ideas here!
# - E & A - made some suggestions for featuring individual chili varieties:
#     making a Scoville Spice-o-meter for countries;
#     different "Playing cards" with info for all the different chilis
#     Spice-o-meter for Countries with 1-5 Star (Or Chili) Rating system
#
# --> We should def. make our own df columns - TODO
#     SPECIES =["Capsicum annum", "C. chinensis.." etc] and VARIETY =["Bhut Jolokia", "BirdsEye", "Jalapeno"...]
#     PIVOT table - [Species] [Variety] df
#         --> make [Species] and [Variety] lists and dfs in WIDE format - TODO NN.!
#
#     - GLOBAL Pungency Index - country comparison/map, codifying High Scoville products --> A: if time, low priority for Day4
#         --> A: will look at codifying "spiciness" by Scoville scale and country, in progress - see "planning file" ipynb on GH
#         --> M: dive further into Comtrade and find out what Comtrade DS can tell us for sub species / variety? TODO
#
#     - Chili Varieties Lexicon - scrape wikidata objects to make small cards for our types - QUALITATIVE/CATEGORICAL, IMPLIED DATA!
#             Lexicon style for species [capsicum annum, ..] and Varieties lists [jalapeno, jolokia, ...]
#
#         --> E - optimize Wiki Image & Caption scraper? - no rush, if time D4?
#         --> All - provide additional NON QUANT infos to central VARIETIES file - TODO D3&4
#         --> map subspecies Habanero, Piripiri, etc? --> E&A - check what if anything to be done with Chili Variety data -- TODO
#         --> E: example code for wikip. scraping? TODO, low priority
